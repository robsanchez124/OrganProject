# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/guillermo/Downloads/Donor___Donor_Ethnicity_by_Organ,_Donation_Year.csv')
df
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2 All Ethnicities    White   Black  \
# 0    All Donors    To Date         NaN         413,435  290,985  53,737
# 1           NaN       2021         NaN           4,740    3,290     573
# 2           NaN       2020         NaN          18,317   12,378   2,372
# 3           NaN       2019         NaN          19,259   13,057   2,414
# 4           NaN       2018         NaN          17,566   11,810   2,304
# ..          ...        ...         ...             ...      ...     ...
# 245         NaN       1992         NaN              21       17       3
# 246         NaN       1991         NaN              11        7       3
# 247         NaN       1990         NaN               5        5       0
# 248         NaN       1989         NaN               0        0       0
# 249         NaN       1988         NaN               0        0       0
#
#     Hispanic  Unknown   Asian American Indian/Alaska Native Pacific Islander  \
# ...

# %%
df.rename(columns={"Unnamed: 1": "Dates", 'Unnamed: 0': 'Organ'}, inplace = True)
df.drop(['Unnamed: 2', 'Unknown', 'American Indian/Alaska Native', 'Pacific Islander'], axis=1, inplace = True)
df = df.fillna("")
df1 = df[0:13]
df1['White'] = df1['White'].str.replace(',','').astype(int)
df1['Black'] = df1['Black'].str.replace(',','').astype(int)
df1['Hispanic'] = df1['Hispanic'].str.replace(',','').astype(int)
df1['Asian'] = df1['Asian'].str.replace(',','').astype(int)
df1['Multiracial'] = df1['Multiracial'].str.replace(',','').astype(int)
df1['All Ethnicities'] = df1['All Ethnicities'].str.replace(',', '').astype(int)
df1
# Out:
# <ipython-input-13-96a9f82b2f3e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['White'] = df1['White'].str.replace(',','').astype(int)
# <ipython-input-13-96a9f82b2f3e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Black'] = df1['Black'].str.replace(',','').astype(int)
# <ipython-input-13-96a9f82b2f3e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
plot1 = df1.loc[2:12]
plot1.drop(['All Ethnicities', 'Organ', 'Dates'], axis = 1, inplace = True)
plot1.values
years = ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# # Plot chart of donations by ethnicity by year.

# %%
fig1, ax = plt.subplots(figsize =(10,7))
eth_labels = ['White', ]
plt.plot(np.flip(years),np.flip(plot1.values), label = ['Multiracial', 'Asian', 'Hispanic', 'African American', 'White'], marker = "o")
# label the legend
plt.legend()
plt.show()
